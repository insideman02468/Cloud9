# %%
def f(x, a, b):
    return a * x + b

# %%
from ipywidgets import interact

# %%
interact(f, x=(-10,10, 1), a=(-10,10, 1), b=(-10,10, 1))
# Out:
# -7

# %%
from PIL import Image
img = Image.open('testfig1.jpg').convert('L')

# %%
@interact
def binarize(th: (0, 255, 1)):
    return img.point(lambda p: 255 if p > th else 0)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7F6E3C0CE048>

# %%
orig = Image.open('testfig1.jpg')

@interact
def github_diff(percentage: (0, 100, 1)):
    orig_copied = orig.copy()
    box = (int(img.width / 100 * percentage), 0, img.width, img.height)
    img_cropped = img.crop(box)
    orig_copied.paste(img_cropped, box)
    return orig_copied
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F6E3C06DCC0>
